# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Conditional Selection

# %%
df=pd.read_csv('ramen-ratings.csv')

# %%
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# To explore data , ask intersting questions

# %% [markdown]
# Explore ramen dishes served in Taiwan

# %%
df.loc[df['Country'] =='Taiwan'] # Select all rows when country == Taiwan
# Out:
#       Review #             Brand  \
# 1         2579          Just Way
# 3         2577           Wei Lih
# 40        2540           Wei Lih
# 65        2515     Uni-President
# 68        2512  Mom's Dry Noodle
# ...        ...               ...
# 2500        80     Unif / Tung-I
# 2512        68           Wei Lih
# 2522        58           Ve Wong
# 2537        43       Kim Ve Wong
# 2572         8            Tung-I
#
#                                                 Variety Style Country Stars  \
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 3                         GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 40        GGE Noodle Snack Wheat Crackers Mexican Spicy  Pack  Taiwan  3.25
# 65      Man Han Feast Spicy Beef Flavor Instant Noodles  Bowl  Taiwan     5
# 68                                       Dan Dan Noodle  Pack  Taiwan     5
# ...                                                 ...   ...     ...   ...
# ...

# %% [markdown]
# Have a look at the raman dishes which have rating above than average

# %%
# When trying to get the stars more than 2.5 as avg this give an error as data 
# the stars column is str not float as there are some values 'unrates'

# %%
df=df.loc[df.Stars != 'Unrated'] # to delete all rows which stars value==unrated

# %%
df.Stars.astype(float) # change type of data to float
# Out:
# 0       3.75
# 1       1.00
# 2       2.25
# 3       2.75
# 4       3.75
#         ...
# 2575    3.50
# 2576    1.00
# 2577    2.00
# 2578    2.00
# 2579    0.50
# Name: Stars, Length: 2577, dtype: float64

# %%
df.Stars
# Out:
# 0       3.75
# 1       1.00
# 2       2.25
# 3       2.75
# 4       3.75
#         ...
# 2575    3.50
# 2576    1.00
# 2577    2.00
# 2578    2.00
# 2579    0.50
# Name: Stars, Length: 2577, dtype: float64

# %%
df.loc[df.Stars > 2.5]
# Out:
#       Review #            Brand  \
# 0         2580        New Touch
# 3         2577          Wei Lih
# 4         2576   Ching's Secret
# 5         2575    Samyang Foods
# 6         2574          Acecook
# ...        ...              ...
# 2564        16          Samyang
# 2566        14          Samyang
# 2567        13  Sapporo Ichiban
# 2572         8           Tung-I
# 2575         5            Vifon
#
#                                                 Variety Style      Country  \
# 0                             T's Restaurant Tantanmen    Cup        Japan
# 3                         GGE Ramen Snack Tomato Flavor  Pack       Taiwan
# 4                                       Singapore Curry  Pack        India
# 5                                Kimchi song Song Ramen  Pack  South Korea
# 6                   Spice Deli Tantan Men With Cilantro   Cup        Japan
# ...                                                 ...   ...          ...
# ...

# %% [markdown]
# Served dishes in Taiwan with above average ratings

# %%
# & and  , | or , ~ not 
df.loc[(df['Country'] =='Taiwan') & (df['Stars'] > 2.5)]
# Out:
#       Review #             Brand  \
# 3         2577           Wei Lih
# 40        2540           Wei Lih
# 65        2515     Uni-President
# 68        2512  Mom's Dry Noodle
# 79        2501        Happy Cook
# ...        ...               ...
# 2499        81     Unif / Tung-I
# 2500        80     Unif / Tung-I
# 2512        68           Wei Lih
# 2522        58           Ve Wong
# 2572         8            Tung-I
#
#                                                 Variety Style Country  Stars  \
# 3                         GGE Ramen Snack Tomato Flavor  Pack  Taiwan   2.75
# 40        GGE Noodle Snack Wheat Crackers Mexican Spicy  Pack  Taiwan   3.25
# 65      Man Han Feast Spicy Beef Flavor Instant Noodles  Bowl  Taiwan   5.00
# 68                                       Dan Dan Noodle  Pack  Taiwan   5.00
# 79                                   Toona Paste Noodle  Pack  Taiwan   4.00
# ...                                                 ...   ...     ...    ...
# ...

# %%
df.loc[(df['Country'] =='Taiwan') & (df['Stars'] > 2.5) , ['Brand','Style']]
# Out:
#                  Brand Style
# 3              Wei Lih  Pack
# 40             Wei Lih  Pack
# 65       Uni-President  Bowl
# 68    Mom's Dry Noodle  Pack
# 79          Happy Cook  Pack
# ...                ...   ...
# 2499     Unif / Tung-I  Pack
# 2500     Unif / Tung-I  Pack
# 2512           Wei Lih  Pack
# 2522           Ve Wong  Pack
# 2572            Tung-I  Pack
#
# [191 rows x 2 columns]

# %% [markdown]
# Have a look at the dishes served in both Finland and sweden

# %%
df.loc[(df['Country']=='Finland') | (df['Country']=='Sweden')]
# Out:
#       Review #   Brand                                Variety Style  Country  \
# 675       1905  Pirkka           Nuudeli Kana Nudlar Kyckling  Pack  Finland
# 816       1764  Pirkka              Nuudeli Tom Yum Katkarapu  Pack  Finland
# 856       1724  Pirkka               Nuudeli Liha Nudlar Kott  Pack  Finland
# 1026      1554     ICA  Asia Fast Noodles Snabbnudlar Räksmak  Pack   Sweden
# 1063      1517   Katoz            Instant Noodles Spicy Chili  Pack   Sweden
# 1093      1487     ICA          Asia Snabbnudlar Kycklingsmak  Pack   Sweden
#
#       Stars Top Ten
# 675    3.50     NaN
# 816    3.75     NaN
# 856    3.50     NaN
# 1026   3.00     NaN
# 1063   3.50     NaN
# 1093   3.25     NaN

# %%
df.loc[df.Country.isin(['Finland','Sweden'])]
# Out:
#       Review #   Brand                                Variety Style  Country  \
# 675       1905  Pirkka           Nuudeli Kana Nudlar Kyckling  Pack  Finland
# 816       1764  Pirkka              Nuudeli Tom Yum Katkarapu  Pack  Finland
# 856       1724  Pirkka               Nuudeli Liha Nudlar Kott  Pack  Finland
# 1026      1554     ICA  Asia Fast Noodles Snabbnudlar Räksmak  Pack   Sweden
# 1063      1517   Katoz            Instant Noodles Spicy Chili  Pack   Sweden
# 1093      1487     ICA          Asia Snabbnudlar Kycklingsmak  Pack   Sweden
#
#       Stars Top Ten
# 675    3.50     NaN
# 816    3.75     NaN
# 856    3.50     NaN
# 1026   3.00     NaN
# 1063   3.50     NaN
# 1093   3.25     NaN

# %% [markdown]
# Get the Top Ten values that are not null

# %%
df.loc[~df['Top Ten'].isnull()]
# Out:
#       Review #             Brand  \
# 616       1964              MAMA
# 633       1947       Prima Taste
# 655       1925             Prima
# 673       1907       Prima Taste
# 752       1828     Tseng Noodles
# 891       1689      Wugudaochang
# 942       1638  A-Sha Dry Noodle
# 963       1617           MyKuali
# 995       1585            CarJEN
# 1059      1521          Maruchan
# 1072      1508             Mamee
# 1080      1500           MyKuali
# 1109      1471              Mama
# 1114      1466              Mama
# 1230      1350             Mamee
# 1250      1330   Sapporo Ichiban
# 1272      1308          Nongshim
# 1278      1302              Mama
# 1309      1271       Prima Taste
# 1382      1198     Samyang Foods
# 1397      1183             Paldo
# 1493      1087           MyKuali
# 1588       992       Prima Taste
# 1589       991       Prima Taste
# 1646       934          Nongshim
# 1670       910             Paldo
# 1757       823             Paldo
# ...

# %%
df.loc[df['Top Ten'].notnull()]
# Out:
#       Review #             Brand  \
# 616       1964              MAMA
# 633       1947       Prima Taste
# 655       1925             Prima
# 673       1907       Prima Taste
# 752       1828     Tseng Noodles
# 891       1689      Wugudaochang
# 942       1638  A-Sha Dry Noodle
# 963       1617           MyKuali
# 995       1585            CarJEN
# 1059      1521          Maruchan
# 1072      1508             Mamee
# 1080      1500           MyKuali
# 1109      1471              Mama
# 1114      1466              Mama
# 1230      1350             Mamee
# 1250      1330   Sapporo Ichiban
# 1272      1308          Nongshim
# 1278      1302              Mama
# 1309      1271       Prima Taste
# 1382      1198     Samyang Foods
# 1397      1183             Paldo
# 1493      1087           MyKuali
# 1588       992       Prima Taste
# 1589       991       Prima Taste
# 1646       934          Nongshim
# 1670       910             Paldo
# 1757       823             Paldo
# ...

# %% [markdown]
# # Assigning Data

# %% [markdown]
# Assign values of specific column by specific values

# %%
df.loc['Brand']='Doll'
df
# Out:
#       Review #  Brand                                            Variety  \
# 0       2580.0   Doll                          T's Restaurant Tantanmen
# 1       2579.0   Doll  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2       2578.0   Doll                      Cup Noodles Chicken Vegetable
# 3       2577.0   Doll                      GGE Ramen Snack Tomato Flavor
# 4       2576.0   Doll                                    Singapore Curry
# ...        ...    ...                                                ...
# 2577       3.0   Doll                                     Tom Yum Shrimp
# 2578       2.0   Doll                               Tom Yum Chili Flavor
# 2579       1.0   Doll                                         Miso Ramen
# isCup      NaN  False                                                NaN
# Brand     Doll   Doll                                               Doll
#
#       Style   Country Stars Top Ten  isCup
# 0       Cup     Japan  3.75     NaN    1.0
# ...

# %% [markdown]
# Adding a new column to table

# %%
df.loc['isCup']=(df.Style=='Cup')
df
# Out:
#       Review #  Brand                                            Variety  \
# 0       2580.0   Doll                          T's Restaurant Tantanmen
# 1       2579.0   Doll  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2       2578.0   Doll                      Cup Noodles Chicken Vegetable
# 3       2577.0   Doll                      GGE Ramen Snack Tomato Flavor
# 4       2576.0   Doll                                    Singapore Curry
# ...        ...    ...                                                ...
# 2577       3.0   Doll                                     Tom Yum Shrimp
# 2578       2.0   Doll                               Tom Yum Chili Flavor
# 2579       1.0   Doll                                         Miso Ramen
# isCup      NaN  False                                                NaN
# Brand     Doll   Doll                                               Doll
#
#       Style   Country Stars Top Ten  isCup
# 0       Cup     Japan  3.75     NaN    1.0
# ...

# %% [markdown]
# Replce values of Review # column to 1 to len of data

# %%
len(df)
# Out:
# 2579

# %%
df['Review #']=list(range(1,2580))  # note range (1 to len(df)+1)
df
# Out:
#        Review #  Brand                                            Variety  \
# 0             1   Doll                          T's Restaurant Tantanmen
# 1             2   Doll  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2             3   Doll                      Cup Noodles Chicken Vegetable
# 3             4   Doll                      GGE Ramen Snack Tomato Flavor
# 4             5   Doll                                    Singapore Curry
# ...         ...    ...                                                ...
# 2577       2575   Doll                                     Tom Yum Shrimp
# 2578       2576   Doll                               Tom Yum Chili Flavor
# 2579       2577   Doll                                         Miso Ramen
# isCup      2578  False                                                NaN
# Brand      2579   Doll                                               Doll
#
#       Style   Country Stars Top Ten  isCup
# ...
