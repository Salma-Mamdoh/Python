# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
taitanic=sns.load_dataset('titanic')

# %%
taitanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
taitanic['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
taitanic['who'].value_counts()
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %%
taitanic.pivot_table(index='who' ,columns='class' , values='age' , aggfunc='mean' )
# Out:
# class      First     Second      Third
# who
# child   7.820000   4.543684   6.817586
# man    42.382653  33.588889  28.995556
# woman  35.500000  32.179688  27.854167

# %%
taitanic.pivot_table(index='sex' , values='survived' , aggfunc='mean' ,columns='class')
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
taitanic.pivot_table(index='who' , values=['survived','age'] , aggfunc={'survived':'count' , 'age':'mean'} ,columns='class')
# Out:
#              age                       survived
# class      First     Second      Third    First Second Third
# who
# child   7.820000   4.543684   6.817586        6     19    58
# man    42.382653  33.588889  28.995556      119     99   319
# woman  35.500000  32.179688  27.854167       91     66   114

# %%
taitanic.pivot_table(index=['who','sex'] , values=['survived','age'] , aggfunc={'survived':'count' , 'age':'mean'} ,columns='class')
# Out:
#                     age                       survived
# class             First     Second      Third    First Second Third
# who   sex
# child female  10.333333   6.600000   7.100000        3     10    30
#       male     5.306667   2.258889   6.515000        3      9    28
# man   female        NaN        NaN        NaN        0      0     0
#       male    42.382653  33.588889  28.995556      119     99   319
# woman female  35.500000  32.179688  27.854167       91     66   114
#       male          NaN        NaN        NaN        0      0     0
